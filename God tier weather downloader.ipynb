# %%
from bs4 import BeautifulSoup as BS
from selenium import webdriver
from functools import reduce
import pandas as pd
import time
import numpy as np
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# %%
# function to load wunderground data (without this it has no records to show)
def render_page(url):
    options = Options()
    options.headless = True
    driver = webdriver.Chrome(options=options, executable_path='/Users/earthnote/Documents/chromedriver')
    driver.get(url)
    time.sleep(7)
    r = driver.page_source
    time.sleep(3)
    driver.quit()
    return r

# %%
# function to scrape wunderground
def scraper(page, dates):
    output = pd.DataFrame()

    for d in dates:

        url = str(str(page) + str(d))

        r = render_page(url)

        soup = BS(r, "html.parser")
        container = soup.find('lib-city-history-observation')
        check = container.find('tbody')

        data = []

        for c in check.find_all('tr', class_='ng-star-inserted'):
            for i in c.find_all('td', class_='ng-star-inserted'):
                trial = i.text
                trial = trial.strip('  ')
                data.append(trial)
        
        # if there's 31 days and a 1 extra day
        if data[31]=='31' and data[32]=='1':
            Temperature = pd.DataFrame([data[33:132][x:x + 3] for x in range(0, len(data[33:132]), 3)][1:],
                                       columns=['Temp_max', 'Temp_avg', 'Temp_min'])
            Dew_Point = pd.DataFrame([data[132:231][x:x + 3] for x in range(0, len(data[132:231]), 3)][1:],
                                           columns=['Dew_max', 'Dew_avg', 'Dew_min'])
            Humidity = pd.DataFrame([data[231:330][x:x + 3] for x in range(0, len(data[231:330]), 3)][1:],
                                           columns=['Hum_max', 'Hum_avg', 'Hum_min'])
            Wind = pd.DataFrame([data[330:429][x:x + 3] for x in range(0, len(data[330:429]), 3)][1:],
                                           columns=['Wind_max', 'Wind_avg', 'Wind_min'])
            Pressure = pd.DataFrame([data[429:528][x:x + 3] for x in range(0, len(data[429:528]), 3)][1:],
                                           columns=['Pres_max', 'Pres_avg', 'Pres_min'])
            Date = pd.DataFrame(data[1:33],columns=['Date'])
            Precipitation = pd.DataFrame(data[528:][1:], columns=['Precipitation'])
            print(str(str(d) + ' finished!'))


        #if there's 28 days and 1 extra day
        elif data[28]=='28' and data[29]=='1':
            Temperature = pd.DataFrame([data[30:120][x:x + 3] for x in range(0, len(data[30:120]), 3)][1:],
                                       columns=['Temp_max', 'Temp_avg', 'Temp_min'])

            Dew_Point = pd.DataFrame([data[120:210][x:x + 3] for x in range(0, len(data[120:210]), 3)][1:],
                                               columns=['Dew_max', 'Dew_avg', 'Dew_min'])

            Humidity = pd.DataFrame([data[210:300][x:x + 3] for x in range(0, len(data[210:300]), 3)][1:],
                                               columns=['Hum_max', 'Hum_avg', 'Hum_min'])

            Wind = pd.DataFrame([data[300:390][x:x + 3] for x in range(0, len(data[300:390]), 3)][1:],
                                               columns=['Wind_max', 'Wind_avg', 'Wind_min'])

            Pressure = pd.DataFrame([data[390:480][x:x + 3] for x in range(0, len(data[390:480]), 3)][1:],
                                               columns=['Pres_max', 'Pres_avg', 'Pres_min'])
            Date = pd.DataFrame(data[1:30],columns=['Date'])
            Precipitation = pd.DataFrame(data[480:][1:], columns=['Precipitation'])

            print(str(str(d) + ' finished!'))


        #if there's 31 days and no extra days
        elif data[31]=='31' and data[32]!='1':
            Temperature = pd.DataFrame([data[32:128][x:x + 3] for x in range(0, len(data[32:128]), 3)][1:],
                                       columns=['Temp_max', 'Temp_avg', 'Temp_min'])
            Dew_Point = pd.DataFrame([data[128:224][x:x + 3] for x in range(0, len(data[128:224]), 3)][1:],
                                     columns=['Dew_max', 'Dew_avg', 'Dew_min'])
            Humidity = pd.DataFrame([data[224:320][x:x + 3] for x in range(0, len(data[224:320]), 3)][1:],
                                    columns=['Hum_max', 'Hum_avg', 'Hum_min'])
            Wind = pd.DataFrame([data[320:416][x:x + 3] for x in range(0, len(data[320:416]), 3)][1:],
                                columns=['Wind_max', 'Wind_avg', 'Wind_min'])
            Pressure = pd.DataFrame([data[416:512][x:x + 3] for x in range(0, len(data[416:512]), 3)][1:],
                                    columns=['Pres_max', 'Pres_avg', 'Pres_min'])
            Date = pd.DataFrame(data[:32][1:], columns=['Date'])
            Precipitation = pd.DataFrame(data[512:][1:], columns=['Precipitation'])

            print(str(str(d) + ' finished!'))


        #if there's 30 days and no extra days
        elif data[30]=='30' and data[31]!='31' and data[31]!='1':
            Temperature = pd.DataFrame([data[31:124][x:x + 3] for x in range(0, len(data[31:124]), 3)][1:],
                                       columns=['Temp_max', 'Temp_avg', 'Temp_min'])
            Dew_Point = pd.DataFrame([data[124:217][x:x + 3] for x in range(0, len(data[124:217]), 3)][1:],
                                     columns=['Dew_max', 'Dew_avg', 'Dew_min'])
            Humidity = pd.DataFrame([data[217:310][x:x + 3] for x in range(0, len(data[217:310]), 3)][1:],
                                    columns=['Hum_max', 'Hum_avg', 'Hum_min'])
            Wind = pd.DataFrame([data[310:403][x:x + 3] for x in range(0, len(data[310:403]), 3)][1:],
                                columns=['Wind_max', 'Wind_avg', 'Wind_min'])
            Pressure = pd.DataFrame([data[403:496][x:x + 3] for x in range(0, len(data[403:496]), 3)][1:],
                                    columns=['Pres_max', 'Pres_avg', 'Pres_min'])
            Date = pd.DataFrame(data[:31][1:], columns=['Date'])
            Precipitation = pd.DataFrame(data[496:][1:], columns=['Precipitation'])

            print(str(str(d) + ' finished!'))


        #if there's 30 days and 1 extra day
        elif data[30]=='30' and data[31]=='1':
            Temperature = pd.DataFrame([data[32:128][x:x + 3] for x in range(0, len(data[32:128]), 3)][1:],
                                       columns=['Temp_max', 'Temp_avg', 'Temp_min'])
            Dew_Point = pd.DataFrame([data[128:224][x:x + 3] for x in range(0, len(data[128:224]), 3)][1:],
                                     columns=['Dew_max', 'Dew_avg', 'Dew_min'])
            Humidity = pd.DataFrame([data[224:320][x:x + 3] for x in range(0, len(data[224:320]), 3)][1:],
                                    columns=['Hum_max', 'Hum_avg', 'Hum_min'])
            Wind = pd.DataFrame([data[320:416][x:x + 3] for x in range(0, len(data[320:416]), 3)][1:],
                                columns=['Wind_max', 'Wind_avg', 'Wind_min'])
            Pressure = pd.DataFrame([data[416:512][x:x + 3] for x in range(0, len(data[416:512]), 3)][1:],
                                    columns=['Pres_max', 'Pres_avg', 'Pres_min'])
            Date = pd.DataFrame(data[:32][1:], columns=['Date'])
            Precipitation = pd.DataFrame(data[512:][1:], columns=['Precipitation'])

            print(str(str(d) + ' finished!'))

        #if there's 29 days and 1 extra day
        elif data[29]=='29' and data[30]=='1':
            Temperature = pd.DataFrame([data[31:124][x:x + 3] for x in range(0, len(data[31:124]), 3)][1:],
                                       columns=['Temp_max', 'Temp_avg', 'Temp_min'])
            Dew_Point = pd.DataFrame([data[124:217][x:x + 3] for x in range(0, len(data[124:217]), 3)][1:],
                                     columns=['Dew_max', 'Dew_avg', 'Dew_min'])
            Humidity = pd.DataFrame([data[217:310][x:x + 3] for x in range(0, len(data[217:310]), 3)][1:],
                                    columns=['Hum_max', 'Hum_avg', 'Hum_min'])
            Wind = pd.DataFrame([data[310:403][x:x + 3] for x in range(0, len(data[310:403]), 3)][1:],
                                columns=['Wind_max', 'Wind_avg', 'Wind_min'])
            Pressure = pd.DataFrame([data[403:496][x:x + 3] for x in range(0, len(data[403:496]), 3)][1:],
                                    columns=['Pres_max', 'Pres_avg', 'Pres_min'])
            Date = pd.DataFrame(data[:31][1:], columns=['Date'])
            Precipitation = pd.DataFrame(data[496:][1:], columns=['Precipitation'])

            print(str(str(d) + ' finished!'))

        #if there's 29 days and no extra days
        elif data[29]=='29' and data[30]!='30' and data[30]!='1':

            Temperature = pd.DataFrame([data[30:120][x:x + 3] for x in range(0, len(data[30:120]), 3)][1:],
                                       columns=['Temp_max', 'Temp_avg', 'Temp_min'])
            Dew_Point = pd.DataFrame([data[120:210][x:x + 3] for x in range(0, len(data[120:210]), 3)][1:],
                                     columns=['Dew_max', 'Dew_avg', 'Dew_min'])
            Humidity = pd.DataFrame([data[210:300][x:x + 3] for x in range(0, len(data[210:300]), 3)][1:],
                                    columns=['Hum_max', 'Hum_avg', 'Hum_min'])
            Wind = pd.DataFrame([data[300:390][x:x + 3] for x in range(0, len(data[300:390]), 3)][1:],
                                columns=['Wind_max', 'Wind_avg', 'Wind_min'])
            Pressure = pd.DataFrame([data[390:480][x:x + 3] for x in range(0, len(data[390:480]), 3)][1:],
                                    columns=['Pres_max', 'Pres_avg', 'Pres_min'])
            Date = pd.DataFrame(data[:30][1:], columns=['Date'])
            Precipitation = pd.DataFrame(data[480:][1:], columns=['Precipitation'])

            print(str(str(d) + ' finished!'))
        
        #if there's 28 days and no extra days
        elif data[28]=='28' and data[29]!='29' and data[29]!='1':
            
            Temperature = pd.DataFrame([data[29:116][x:x + 3] for x in range(0, len(data[29:116]), 3)][1:],
                                       columns=['Temp_max', 'Temp_avg', 'Temp_min'])
            Dew_Point = pd.DataFrame([data[116:203][x:x + 3] for x in range(0, len(data[116:203]), 3)][1:],
                                     columns=['Dew_max', 'Dew_avg', 'Dew_min'])
            Humidity = pd.DataFrame([data[203:290][x:x + 3] for x in range(0, len(data[203:290]), 3)][1:],
                                    columns=['Hum_max', 'Hum_avg', 'Hum_min'])
            Wind = pd.DataFrame([data[290:377][x:x + 3] for x in range(0, len(data[290:377]), 3)][1:],
                                columns=['Wind_max', 'Wind_avg', 'Wind_min'])
            Pressure = pd.DataFrame([data[377:464][x:x + 3] for x in range(0, len(data[377:463]), 3)][1:],
                                    columns=['Pres_max', 'Pres_avg', 'Pres_min'])
            Date = pd.DataFrame(data[:29][1:], columns=['Date'])
            Precipitation = pd.DataFrame(data[464:][1:], columns=['Precipitation'])
            
            print(str(str(d) + ' finished!'))
        
        else:
            print('Data not in normal length')
            Temperature = pd.DataFrame(np.array([[0, 0, 0]]),
                                       columns=['Temp_max', 'Temp_avg', 'Temp_min'])
            Dew_Point = pd.DataFrame(np.array([[0, 0, 0]]),
                                     columns=['Dew_max', 'Dew_avg', 'Dew_min'])
            Humidity = pd.DataFrame(np.array([[0, 0, 0]]),
                                    columns=['Hum_max', 'Hum_avg', 'Hum_min'])
            Wind = pd.DataFrame(np.array([[0, 0, 0]]),
                                columns=['Wind_max', 'Wind_avg', 'Wind_min'])
            Pressure = pd.DataFrame(np.array([[0, 0, 0]]),
                                    columns=['Pres_max', 'Pres_avg', 'Pres_min'])
            Date = pd.DataFrame([0], columns=['Date'])
            Precipitation = pd.DataFrame([0], columns=['Precipitation'])
        

        dfs = [Date, Temperature, Dew_Point, Humidity, Wind, Pressure, Precipitation]

        df_final = reduce(lambda left, right: pd.merge(left, right, left_index=True, right_index=True), dfs)


        output = output.append(df_final)

    print('Scraper done!')

    output = output[['Date','Temp_max','Temp_avg', 'Temp_min', 'Dew_max', 'Dew_avg', 'Dew_min', 'Hum_max',
                     'Hum_avg', 'Hum_min', 'Wind_max', 'Wind_avg', 'Wind_min', 'Pres_max',
                     'Pres_avg', 'Pres_min', 'Precipitation']]

    return output

# %%
page = 'https://www.wunderground.com/history/monthly/us/va/fredericksburg/KEZF/date/'

dates = ['2013-1', '2013-2', '2013-3', '2013-4', '2013-5','2013-6', '2013-7','2013-8', '2013-9', '2013-10', '2013-11', '2013-12']         
df = scraper(page, dates)
df.to_csv('frd2013.csv')
del df
# Out:
# 2013-1 finished!
# 2013-2 finished!
# 2013-3 finished!
# 2013-4 finished!
# Data not in normal length
# 2013-6 finished!
# 2013-7 finished!
# 2013-8 finished!
# 2013-9 finished!
# 2013-10 finished!
# 2013-11 finished!
# 2013-12 finished!
# Scraper done!

# %%
page = 'https://www.wunderground.com/history/monthly/us/va/fredericksburg/KEZF/date/'

dates = ['2014-1', '2014-2', '2014-3', '2014-4', '2014-5','2014-6', '2014-7','2014-8', '2014-9', '2014-10', '2014-11', '2014-12']
df = scraper(page, dates)
df.to_csv('frd2014.csv')
del df

dates = ['2015-1', '2015-2', '2015-3', '2015-4', '2015-5','2015-6', '2015-7','2015-8', '2015-9', '2015-10', '2015-11', '2015-12']
df = scraper(page, dates)
df.to_csv('frd2015.csv')
del df
# Out:
# 2014-1 finished!
# 2014-2 finished!
# 2014-3 finished!
# 2014-4 finished!
# 2014-5 finished!
# 2014-6 finished!
# 2014-7 finished!
# 2014-8 finished!
# 2014-9 finished!
# 2014-10 finished!
# 2014-11 finished!
# 2014-12 finished!
# Scraper done!
# 2015-1 finished!
# 2015-2 finished!
# 2015-3 finished!
# 2015-4 finished!
# 2015-5 finished!
# 2015-6 finished!
# 2015-7 finished!
# 2015-8 finished!
# 2015-9 finished!
# 2015-10 finished!
# 2015-11 finished!
# 2015-12 finished!
# Scraper done!

# %%
page = 'https://www.wunderground.com/history/monthly/us/va/fredericksburg/KEZF/date/'

dates = ['2016-1', '2016-2', '2016-3', '2016-4', '2016-5','2016-6', '2016-7','2016-8', '2016-9', '2016-10', '2016-11', '2016-12']
df = scraper(page, dates)
df.to_csv('frd2016.csv')
del df
# Out:
# 2016-1 finished!
# 2016-2 finished!
# 2016-3 finished!
# 2016-4 finished!
# Data not in normal length
# 2016-6 finished!
# 2016-7 finished!
# 2016-8 finished!
# 2016-9 finished!
# 2016-10 finished!
# 2016-11 finished!
# 2016-12 finished!
# Scraper done!

# %%
page = 'https://www.wunderground.com/history/monthly/us/va/fredericksburg/KEZF/date/'

dates=['2017-1', '2017-2', '2017-3', '2017-4', '2017-5','2017-6', '2017-7','2017-8', '2017-9', '2017-10', '2017-11', '2017-12']
df = scraper(page, dates)
df.to_csv('frd2017.csv')
del df
# Out:
# 2017-1 finished!
# 2017-2 finished!
# 2017-3 finished!
# 2017-4 finished!
# 2017-5 finished!
# 2017-6 finished!
# 2017-7 finished!
# 2017-8 finished!
# 2017-9 finished!
# 2017-10 finished!
# 2017-11 finished!
# 2017-12 finished!
# Scraper done!

# %%
page = 'https://www.wunderground.com/history/monthly/us/va/fredericksburg/KEZF/date/'

dates=['2018-1', '2018-2', '2018-3', '2018-4', '2018-5','2018-6', '2018-7','2018-8', '2018-9', '2018-10', '2018-11', '2018-12']
df = scraper(page, dates)
df.to_csv('frd2018.csv')
del df
# Out:
# 2018-1 finished!
# 2018-2 finished!
# 2018-3 finished!
# 2018-4 finished!
# 2018-5 finished!
# 2018-6 finished!
# 2018-7 finished!
# 2018-8 finished!
# 2018-9 finished!
# 2018-10 finished!
# 2018-11 finished!
# 2018-12 finished!
# Scraper done!

# %%
page = 'https://www.wunderground.com/history/monthly/us/va/fredericksburg/KEZF/date/'

dates=['2019-1', '2019-2', '2019-3', '2019-4', '2019-5','2019-6', '2019-7','2019-8', '2019-9', '2019-10', '2019-11', '2019-12']
df = scraper(page, dates)
df.to_csv('frd2019.csv')
del df
# Out:
# 2019-1 finished!
# 2019-2 finished!
# 2019-3 finished!
# 2019-4 finished!
# 2019-5 finished!
# 2019-6 finished!
# 2019-7 finished!
# 2019-8 finished!
# 2019-9 finished!
# 2019-10 finished!
# 2019-11 finished!
# 2019-12 finished!
# Scraper done!

# %%
page = 'https://www.wunderground.com/history/monthly/us/co/broomfield/KBJC/date/'

dates = ['2013-1'] 

output = pd.DataFrame()

for d in dates:
    url = str(str(page) + str(d))
    r = render_page(url)

    soup = BS(r, "html.parser")
    container = soup.find('lib-city-history-observation')
    check = container.find('tbody')

    data = []

    for c in check.find_all('tr', class_='ng-star-inserted'):
        for i in c.find_all('td', class_='ng-star-inserted'):
            trial = i.text
            trial = trial.strip('  ')
            data.append(trial)

# %%
pd.set_option('display.max_rows', 700)
pd.DataFrame(data)




dfs = [Date, Temperature, Dew_Point, Humidity, Wind, Pressure, Precipitation]
df_final = reduce(lambda left, right: pd.merge(left, right, left_index=True, right_index=True), dfs)


output = output.append(df_final)

output

# %%
page = 'https://www.wunderground.com/history/monthly/us/co/broomfield/KBJC/date/'

dates = ['2018-3']         
df = scraper(page, dates)

# %%
        if data[31]=='31' and data[32]=='1':
            Temperature = pd.DataFrame([data[33:132][x:x + 3] for x in range(0, len(data[33:132]), 3)][1:],
                                       columns=['Temp_max', 'Temp_avg', 'Temp_min'])
            Dew_Point = pd.DataFrame([data[132:231][x:x + 3] for x in range(0, len(data[132:231]), 3)][1:],
                                           columns=['Dew_max', 'Dew_avg', 'Dew_min'])
            Humidity = pd.DataFrame([data[231:330][x:x + 3] for x in range(0, len(data[231:330]), 3)][1:],
                                           columns=['Hum_max', 'Hum_avg', 'Hum_min'])
            Wind = pd.DataFrame([data[330:429][x:x + 3] for x in range(0, len(data[330:429]), 3)][1:],
                                           columns=['Wind_max', 'Wind_avg', 'Wind_min'])
            Pressure = pd.DataFrame([data[429:528][x:x + 3] for x in range(0, len(data[429:528]), 3)][1:],
                                           columns=['Pres_max', 'Pres_avg', 'Pres_min'])
            Date = pd.DataFrame(data[1:33],columns=['Date'])
            Precipitation = pd.DataFrame(data[528:][1:], columns=['Precipitation'])
            print(str(str(d) + ' finished!'))

# %%
df
