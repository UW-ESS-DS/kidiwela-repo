# %% [markdown]
# #### In order to Demonstrate my ability to navigate python coding such as importing and using basic python modules, assigning variables, performing basic operations such as addition, declaring lists, loops, basic function definitions, I've generated a python code that explores all of them

# %% [markdown]
# # Rock Paper Scissors Lizard Spock GAME
#
# #### Adaptation from the Big Bang Theory TV show
#
# After Installing the Pyfiglet below, Restart the kernal before running the rest of the code

# %%
pip install pyfiglet
# Out:
# Requirement already satisfied: pyfiglet in /Users/earthnote/opt/anaconda3/lib/python3.8/site-packages (0.8.post1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### importing and using basic python modules

# %%
import random
import os
import time
import pyfiglet

# %% [markdown]
# #### basic function definitions
# ##### uses: if else statements, assigning variables, loops

# %%
def clear():
    os.system("clear")
 
# Print Set of instructions for Rock-Paper-Scissors-Lizard-Spock
def rpsls_instructions():
 
    print()
    print("Instructions for Rock-Paper-Scissors-Lizard-Spock : ")
    print()
    print("Scissors cuts Paper")
    print("Paper covers Rock")
    print("Rock crushes Lizard")
    print("Lizard poisons Spock")
    print("Spock smashes Scissors")
    print("Scissors decapitates Lizard")
    print("Lizard eats Paper")
    print("Paper disproves Spock")
    print("Spock vaporizes Rock")
    print("Rock crushes Scissors")
    print()
 
def rps():
     
    global rps_table
    global game_map
    global name
    
    ComputerCount = 0
    PlayerCount = 0
 
    # Game Loop for each game of Rock-Paper-Scissors
    while True:
 
        print("--------------------------------------")
        print("\t\tMenu")
        print("--------------------------------------")
        print("Enter \"help\" for instructions")
        print("Enter \"Rock\",\"Paper\",\"Scissors\" to play")
        print("Enter \"exit\" to quit")
        print("--------------------------------------")
 
        print()
 
        # Player Input
        inp = input("Enter your move : ")
 
        if inp.lower() == "help":
            clear()
            rps_instructions()
            continue
        elif inp.lower() == "exit":
            clear()
            break  
        elif inp.lower() == "rock":
            player_move = 0
        elif inp.lower() == "paper":
            player_move = 1    
        elif inp.lower() == "scissors":
            player_move = 2
        else:
            clear()
            continue
 
        print("Computer making a move....")
        print()
 
        # Get the computer move randomly
        comp_move = random.randint(0, 2)
 
        # Print the computer move
        print("Computer chooses ", game_map[comp_move].upper())
 
        # Find the winner of the match
        winner = rps_table[player_move][comp_move]
 
        # Declare the winner 
        if winner == player_move:
            print(name, "WINS!!!")
        elif winner == comp_move:
            print("COMPUTER WINS!!!")
        else:
            print("TIE GAME")
 
        print()
        time.sleep(2)
        clear()


def rpsls():
     
    global rpsls_table
    global game_map
    global name
 
    ComputerCount = 0
    PlayerCount = 0
        
    # Game Loop for each game of Rock-Paper-Scissors-Lizard-Spock
    while True:
        print("--------------------------------------")
        print("\t\tMenu")
        print("--------------------------------------")
        print("Enter \"help\" for instructions")
        print("Enter \"Rock\",\"Paper\",\"Scissors\",\"Lizard\",\"Spock\" to play")
        print("Enter \"exit\" to quit")
        print("--------------------------------------")
         
        print()
        
        
 
        # Player Input
        inp = input("Enter your move : ")
 
        if inp.lower() == "help":
            clear()
            rpsls_instructions()
            continue
        elif inp.lower() == "exit":
            clear()
            break  
        elif inp.lower() == "rock":
            player_move = 0
        elif inp.lower() == "paper":
            player_move = 1    
        elif inp.lower() == "scissors":
            player_move = 2
        elif inp.lower() == "lizard":
            player_move = 3
        elif inp.lower() == "spock":
            player_move = 4
        else:
            clear()
            continue
 
 
        print("Computer making a move....")
        from time import sleep
        import sys

        for i in range(21):
            sys.stdout.write('\r')
            # the exact output you're looking for:
            sys.stdout.write("[%-1s] %d%%" % ('='*i, 5*i))
            sys.stdout.flush()
            sleep(0.1)
 
        comp_move = random.randint(0, 4)
        print()
 
        print("Computer chooses ", game_map[comp_move].upper())
 
        winner = rpsls_table[player_move][comp_move]
        print()
        if winner == player_move:
            ascii_banner = pyfiglet.figlet_format(name+" WINS")
            print(ascii_banner)
            
            PlayerCount = PlayerCount+1
            print("Computer: ",ComputerCount," ",name,":",PlayerCount)
            
        elif winner == comp_move:
            ascii_banner = pyfiglet.figlet_format("ROBOT WINS")
            print(ascii_banner)
            ComputerCount = ComputerCount+1
            print("Computer: ",ComputerCount," ",name,":",PlayerCount)
        else:
            ascii_banner = pyfiglet.figlet_format("TIE !!!")
            print(ascii_banner)
            print("Computer: ",ComputerCount," ",name,":",PlayerCount)
        print()
        
        clear()

# %% [markdown]
# ![image.png](attachment:image.png)
#
# #### Run the Game here
#
# ##### Uses: assigning variables, declaring lists, Loops

# %%
if __name__ == '__main__':
 
    # mapping between moves and numbers
    game_map = {0:"rock", 1:"paper", 2:"scissors", 3:"lizard", 4:"Spock"}
 
    # Win-lose matrix for traditional game
    rps_table = [[-1, 1, 0], [1, -1, 2], [0, 2, -1]]
 
    # Win-lose matrix for new version of the game
    rpsls_table = [[-1, 1, 0, 0, 4],[1, -1, 2, 3, 1], [0, 2, -1, 2, 4], [0, 3, 2, -1, 3], [4, 1, 4, 3, -1]]
 
    name = input("Enter your name: ") #assigning variables
    
    # The GAME LOOP
    while True:
 
        # The Game Menu
        print()
        print("Let's Play!!!")
        print("Enter 1 to play Rock-Paper-Scissors-Lizard-Spock")
        print("Enter 2 to quit")
        print()
 
        # Try block to handle the player choice 
        try:
            choice = int(input("Enter your choice = "))
        except ValueError:
            clear()
            print("Wrong Choice")   
            continue
 
        # Play the new version of the game
        if choice == 1:
            rpsls()
 
        # Quit the GAME LOOP    
        elif choice == 2:
            break
 
        # Other wrong input
        else:
            clear()
            print("Wrong choice. Read instructions carefully.")
# Out:
# Enter your name: Maleen
#
# Let's Play!!!
# Enter 1 to play Rock-Paper-Scissors-Lizard-Spock
# Enter 2 to quit
#
# Enter your choice = 1
# --------------------------------------
# 		Menu
# --------------------------------------
# Enter "help" for instructions
# Enter "Rock","Paper","Scissors","Lizard","Spock" to play
# Enter "exit" to quit
# --------------------------------------
#
# Enter your move : Rock
# Computer making a move....
# [====================] 100%
# Computer chooses  PAPER
#
#  ____   ___  ____   ___ _____  __        _____ _   _ ____
# |  _ \ / _ \| __ ) / _ \_   _| \ \      / /_ _| \ | / ___|
# | |_) | | | |  _ \| | | || |    \ \ /\ / / | ||  \| \___ \
# |  _ <| |_| | |_) | |_| || |     \ V  V /  | || |\  |___) |
# |_| \_\\___/|____/ \___/ |_|      \_/\_/  |___|_| \_|____/
#
#
# Computer:  1   Maleen : 0
#
# --------------------------------------
# 		Menu
# --------------------------------------
# Enter "help" for instructions
# Enter "Rock","Paper","Scissors","Lizard","Spock" to play
# Enter "exit" to quit
# --------------------------------------
#
# Enter your move : Spock
# Computer making a move....
# [====================] 100%
# Computer chooses  ROCK
#
#  __  __       _                  __        _____ _   _ ____
# |  \/  | __ _| | ___  ___ _ __   \ \      / /_ _| \ | / ___|
# | |\/| |/ _` | |/ _ \/ _ \ '_ \   \ \ /\ / / | ||  \| \___ \
# | |  | | (_| | |  __/  __/ | | |   \ V  V /  | || |\  |___) |
# |_|  |_|\__,_|_|\___|\___|_| |_|    \_/\_/  |___|_| \_|____/
#
#
# Computer:  1   Maleen : 1
#
# --------------------------------------
# 		Menu
# --------------------------------------
# Enter "help" for instructions
# Enter "Rock","Paper","Scissors","Lizard","Spock" to play
# Enter "exit" to quit
# --------------------------------------
