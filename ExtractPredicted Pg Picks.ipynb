# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %%
# %cd '/content/drive/Shareddrives/AI_tlPicker'
# !pwd
# !ls
# Out:
# /content/drive/Shareddrives/AI_tlPicker
# /content/drive/Shareddrives/AI_tlPicker
#  AI_tlPicker_DataPrep_b.ipynb	     BRA20E.csv   BRA27Z.csv
#  AI_tlPicker_Run2.ipynb		     BRA20H.csv   BRAPicks13.csv
#  AI_tlPicker_Run3.ipynb		     BRA20N.csv   BRAPicks14.csv
#  AI_tlPicker_Run4.ipynb		     BRA20Z.csv   BRAPicks15.csv
# ' AI_tlPicker_Run.ipynb'	     BRA21E.csv   BRAPicks16.csv
# 'Al_tlPicker Presentation.gslides'   BRA21H.csv   BRAPicks18.csv
#  a.npy				     BRA21N.csv   BRAPicks19.csv
#  BRA13E.csv			     BRA21Z.csv   BRAPicks20.csv
#  BRA13H.csv			     BRA22E.csv   BRAPicks21.csv
#  BRA13N.csv			     BRA22H.csv   BRAPicks22.csv
#  BRA13Z.csv			     BRA22N.csv   BRAPicks23.csv
#  BRA14E.csv			     BRA22Z.csv   BRAPicks24.csv
#  BRA14H.csv			     BRA23E.csv   BRAPicks25.csv
#  BRA14N.csv			     BRA23H.csv   BRAPicks26.csv
#  BRA14Z.csv			     BRA23N.csv   BRAPicks27.csv
#  BRA15E.csv			     BRA23Z.csv  'Copy of New_model8.h5'
#  BRA15H.csv			     BRA24E.csv   event.csv
# ...

# %%
from keras.models import Sequential,load_model
from keras.layers import Dense
from keras.layers.convolutional import MaxPooling1D
from keras.layers import Dense, Conv2D, Flatten, MaxPooling2D,Dropout
import numpy as np
import pandas as pd

# %%
model = load_model('New_model14.h5')

# %%
Output = np.load("Output.npy")
a = np.load("a.npy")

# %%
X_test =a[0:1749]
Y_test = Output[0:1749]

# %%
X_test= X_test.reshape(1749,4,3000,1)
Y_pred=model.predict(X_test)
Y_pred=pd.DataFrame(Y_pred)
Y_pred.columns=['Y_Pred']
Y_pred
# Out:
#         Y_Pred
# 0     3.772985
# 1     3.782826
# 2     3.745245
# 3     3.798344
# 4     3.796916
# ...        ...
# 1744  4.122787
# 1745  4.042085
# 1746  4.023822
# 1747  4.016110
# 1748  3.968358
#
# [1749 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
Y_test = pd.DataFrame(Y_test)
Y_test.columns=['Y_test']
ax= Y_pred.plot(legend=True)
Y_test.plot(ax=ax,figsize=(12,10))

# %%
from matplotlib.pyplot import figure
figure(figsize=(12,10))
plt.plot(Y_test,Y_pred,'.')
plt.plot(np.linspace(1.5,5.5),np.linspace(1.5,5.5))

# %%
Y_pred.to_csv('Y_pred1.csv')
from google.colab import files
files.download("Y_pred1.csv")
